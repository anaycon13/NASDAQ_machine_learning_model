# %%
import pandas as pd
#VIF method for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor 
import numpy as np

path = '/content/drive/Shareddrives/MATH456'
data = pd.read_csv(path + '/Cleaned.csv')

data = data.drop(['quarter','NASDAQCOM'], axis=1)

data = data.rename(columns = {'CUSR0000SEEE': 'CPI Urban Consumers: IT & Hardware - Quarterly', 
                              'PSAVERT' : 'Personal Savings - Quarterly', 
                              'CWSR0000SEEE': 'CPI Urban Wage Earners: IT & Hardware - Quarterly', 
                              'RCCCBBALTOT': 'Credit Card Balances - Quarterly', 
                              'TERMCBCCALLNS': 'Credit Card Interest Rates - Quarterly',
                              'DRTSCLCC': 'Net Percentage of Domestic Banks Tightening Standards for Credit Card Loans - Quarterly'})

def calc_vif(X):
  vif = pd.DataFrame()
  vif["variables"] = X.columns
  vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

  return vif

vif_val = calc_vif(data)

vif_val


#dropping this variable as it has highest VIF
new_data = data.drop(['CPI Urban Wage Earners: IT & Hardware - Quarterly'], axis=1) 

new_vif_val = calc_vif(new_data)

corrSet = new_data.corr()

corrSet

new_vif_val
# Out:
#                                            variables        VIF
# 0     CPI Urban Consumers: IT & Hardware - Quarterly  32.905437
# 1                       Personal Savings - Quarterly   8.313900
# 2                   Credit Card Balances - Quarterly  23.948781
# 3             Credit Card Interest Rates - Quarterly  34.542641
# 4  Net Percentage of Domestic Banks Tightening St...   1.363579
